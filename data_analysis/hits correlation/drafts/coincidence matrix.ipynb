# %% [markdown]
# # Coincidence matrix

# %% [markdown]
# ## Imports and Definitions

# %%
from helper import *
from caen_digitizer import *

# data
import uproot
import numpy as np
import awkward as ak
import polars as pl

# plotting
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from collections import Counter

# %%
# plot settings, increase font sizes
plt.rcParams.update({
    "figure.figsize": (6,4),
    "font.size": 15, 
    "legend.fontsize": 13, 
    "legend.labelspacing": 0.2, 
    "figure.dpi": 100, 
    "text.usetex": False,
    "text.latex.preamble": r"\usepackage{sfmath}",
    "font.family": "sans-serif",
    "font.sans-serif": ["DejaVu Sans"],
})

# %% [markdown]
# ## Read Data

# %%
fileDir = "data"

# %%
runNo = 297

# data = digitizer(f'{fileDir}/run{runNo:06}.root', events=None, channels=[i for i in (17, 27)], signal_filter='converted')

data = digitizer(f'{fileDir}/run{runNo:06}.root', events=None, channels=[i for i in range(17, 27) ], signal_filter='converted')

for i in data.waveforms:
    print(i)
# Out:
# timestamp
# waveTime
# wave
# amplitude
# amplitudeTime
# integral
# tot
# cft
# intensity

# %%
"""
timestamp: seconds UTC
waveTime: sample time
wave: [event, ch, samples(number of poitns captured)]
    we can do data.max(axis = 2) >>> [10000,10]
amplitude: 
amplitudeTime: 
integral: sensor charge
tot: time over threshold, 
cft: 
intensity: 
"""

# %%
def getMaxMask(data):

    ch_event = getMask(0, data)

    for _channel_trigger in range(1,10):

        masked = getMask(_channel_trigger, data)


        if masked[0].shape[0] > ch_event[0].shape[0]:
            ch_event = masked
    

    return ch_event[0]

def getMask(_channel_trigger, data):
    signal_max = data.waveforms['amplitude'][:, _channel_trigger]
    signal_min = data.waveforms['wave'][:, _channel_trigger].min(axis=1)
    mask_event = (signal_min > -15) & (signal_max > 10)

    return np.where(mask_event)

print(getMaxMask(data))

# rate = selected_events / len(data.waveforms['wave'])
# print(f"{len(selected_events)} signal events of {len(data.waveforms['wave'])} total events")



# n = 24
# (triggered_event_n,) = np.argwhere(mask_event)[n]
# print(triggered_event_n)

# mask_event = np.zeros(len(mask_event), dtype=bool)
# mask_event[triggered_event_n] = 1

# for ch in range(10):
#     print(data.waveforms['waveTime'][mask_event, ch].T),
#     print(data.waveforms['wave'][mask_event, ch].T)

print(np.argwhere(getMaxMask(data)))
# print(np.argwhere(mask_event))
# Out:
# [   2    5   11 ... 9996 9998 9999]
# [[   0]
#  [   1]
#  [   2]
#  ...
#  [2641]
#  [2642]
#  [2643]]

# %%
"""
for every wave data.waveforms['wave']


matrix[0][3] += 1

np.argwhere(mask_event)[n]

"""

# %%
def getPairs(mask_event):
    trigger_sets = []
    for i in np.argwhere(mask_event):
        
        i = i[0]


        pair = []
        for k in range(10):


            if data.waveforms["wave"][index][k].max() > 8:
                pair.append(k)
            

            trigger_sets.append(pair)

    # print(trigger_sets)

    trigger_pairs = []
    for i in trigger_sets:
        if len(i) == 2:
            trigger_pairs.append(i)

    return trigger_pairs


# trigger_pairs(mask_event)

# %%
pairs = trigger_pairs

# count the number of unique pairs and convert into a dictionary
pair_counts = Counter(tuple(p) for p in pairs)

# find max index to size the matrix
max_idx = 10

# build matrix
matrix = np.zeros((max_idx+1, max_idx+1), dtype=int)
for (i, j), count in pair_counts.items():
    matrix[i, j] = count


plt.imshow(matrix, cmap="Blues", interpolation="nearest")
plt.colorbar(label="Frequency")
plt.xlabel("Second element of pair")
plt.ylabel("First element of pair")
plt.title("Pair Frequency Heatmap")

plt.xticks(np.arange(matrix.shape[1]))  # 0,1,2 for 3 columns
plt.yticks(np.arange(matrix.shape[0]))  # 0,1,2 for 3 rows

plt.show()

# %%
data.waveforms["wave"][300][9].max()
np.argwhere(mask_event)[1][0]
# Out:
# 14

# %%
run_start = 297
run_end = 303

number_of_runs = run_end - run_start + 1

data_files = []
for runNo in range(run_start, run_end + 1):
    data_files.append(digitizer(f'{fileDir}/run{runNo:06}.root', events=None, channels=[i for i in range(17, 27) ], signal_filter='converted'))


num_col = 5
num_row = number_of_runs // 5 + 1
fig, axes = plt.subplots(num_row,num_col, figsize = (12,6), sharex=True, sharey=True)

axes = axes.flatten()

# find max index to size the matrix(number of channels)
max_idx = 10

for i in range(len(data_files)):

    #Get the selected events
    mask_event = getMaxMask(data_files[i])

    #Get the pairs
    pairs = getPairs(mask_event)

    # count the number of unique pairs and convert into a dictionary
    pair_counts = Counter(tuple(p) for p in pairs)
    


    # build matrix
    matrix = np.zeros((max_idx+1, max_idx+1), dtype=int)
    for (j, k), count in pair_counts.items():
        matrix[j, k] = count
    

    # plot heatmap in the subplot
    ax = axes[i]
    im = ax.imshow(matrix, cmap="Blues", interpolation="nearest")
    ax.set_title(f"Heatmap {i+1}")
    
    # set x and y ticks
    ax.set_xticks(np.arange(matrix.shape[1]))
    ax.set_yticks(np.arange(matrix.shape[0]))

# remove unused subplots
for j in range(number_of_runs, len(axes)):
    fig.delaxes(axes[j])

plt.subplots_adjust(right=0.85)
cbar = fig.colorbar(im, ax=axes[:number_of_runs].tolist(), label="Frequency")


plt.tight_layout()
plt.show()
# Out:
# /var/folders/g3/v7y9h9s955v66q681bphnb740000gn/T/ipykernel_37490/2361336494.py:56: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
run_start = 297
run_end = 303

number_of_runs = run_start - run_end
data_files = []
for runNo in range(run_start, run_end + 1):
    data_files.append(digitizer(f'{fileDir}/run{runNo:06}.root', events=None, channels=[i for i in range(17, 27) ], signal_filter='converted'))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[112], line 7
#       5 data_files = []
#       6 for runNo in range(run_start, run_end + 1):
# ----> 7     data_files.append(digitizer(f'{fileDir}/run{runNo:06}.root', events=None, channels=[i for i in range(17, 27) ], signal_filter='converted'))
#
# File ~/Documents/Python/HEP/dawson_hep/scintillating_chamber/data_analysis/hits correlation/caen_digitizer.py:51, in digitizer.__init__(self, fileName, **kwargs)
#      47 self.__kwargs = kwargs
#      49 self.adc_conversion = 1.1 * 1000 / 2**12 # ADC count to voltage conversion in [mV/ADC count] | +10% from charge injection
# ---> 51 self.__calculate_waveforms()
#
# File ~/Documents/Python/HEP/dawson_hep/scintillating_chamber/data_analysis/hits correlation/caen_digitizer.py:80, in digitizer.__calculate_waveforms(self)
#      77 nChannels = len(list_of_channels)
#      79 # get branches
# ---> 80 branches = tree.arrays([f'ch{i}_data' for i in list_of_channels]+['time', 'xinc', 'timestamp'], library='np')#'TR0_0_data',
#      82 # waveform time per sample in [ns]
#      83 self.sample_size = (branches['xinc'][0] / 1e-9)
#
# File /opt/anaconda3/lib/python3.12/site-packages/uproot/behaviors/TBranch.py:889, in HasBranches.arrays(self, expressions, cut, filter_name, filter_typename, filter_branch, aliases, language, entry_start, entry_stop, decompression_executor, interpretation_executor, array_cache, library, ak_add_doc, how)
#     886                 ranges_or_baskets.append((branch, basket_num, range_or_basket))
#     888 interp_options = {"ak_add_doc": ak_add_doc}
# --> 889 _ranges_or_baskets_to_arrays(
#     890     self,
#     891     ranges_or_baskets,
#     892     branchid_interpretation,
#     893     entry_start,
#     894     entry_stop,
#     895     decompression_executor,
#     896     interpretation_executor,
#     897     library,
#     898     arrays,
#     899     False,
#     900     interp_options,
#     901 )
#     903 # no longer needed; save memory
#     904 del ranges_or_baskets
#
# File /opt/anaconda3/lib/python3.12/site-packages/uproot/behaviors/TBranch.py:3198, in _ranges_or_baskets_to_arrays(hasbranches, ranges_or_baskets, branchid_interpretation, entry_start, entry_stop, decompression_executor, interpretation_executor, library, arrays, update_ranges_or_baskets, interp_options)
#    3195     decompression_executor.submit(chunk_to_basket, obj, *args)
#    3197 elif isinstance(obj, uproot.models.TBasket.Model_TBasket):
# -> 3198     interpretation_executor.submit(basket_to_array, obj)
#    3200 elif obj is None:
#    3201     pass
#
# File /opt/anaconda3/lib/python3.12/site-packages/uproot/source/futures.py:104, in TrivialExecutor.submit(self, task, *args, **kwargs)
#     100 def submit(self, task, /, *args, **kwargs):
#     101     """
#     102     Immediately runs ``task(*args)``.
#     103     """
# --> 104     return TrivialFuture(task(*args, **kwargs))
#
# File /opt/anaconda3/lib/python3.12/site-packages/uproot/behaviors/TBranch.py:3176, in _ranges_or_baskets_to_arrays.<locals>.basket_to_array(basket)
#    3165         arrays[branch.cache_key] = interpretation.final_array(
#    3166             basket_arrays,
#    3167             entry_start,
#    (...)
#    3172             interp_options,
#    3173         )
#    3174         with _basket_arrays_lock:
#    3175             # no longer needed, save memory
# -> 3176             basket_arrays.clear()
#    3178 except Exception:
#    3179     notifications.put(sys.exc_info())
#
# KeyboardInterrupt:

# %%
runNo = 1
data = digitizer(f'{fileDir}/run{runNo:06}.root', events=None, channels=[i for i in range(17, 27) ], signal_filter='converted')
