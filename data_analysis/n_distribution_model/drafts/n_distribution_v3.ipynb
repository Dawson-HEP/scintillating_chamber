# %% [markdown]
# # N-Distribution

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd

# %%
num_data_files = 0

dfs = []
for i in range(num_data_files):
    dfs.append(pd.read_csv(f"data{num_data_files}"))



# time,x,y

# %%
def clean(df):
    time = 1000 #ms
    df = df["time"].clip(upper = )

# %%
max = []
for i in dfs:
